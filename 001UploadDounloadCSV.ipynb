# %% [markdown]
# <a href="https://colab.research.google.com/github/rk1602066/ML_basic/blob/main/001UploadDounloadCSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #upload files from local disk

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0e3a2ac7-effd-454b-b7c2-6c02a9307768" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e3a2ac7-effd-454b-b7c2-6c02a9307768">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mercedesbenz.csv to mercedesbenz.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('mercedesbenz.csv')
df.head()
# Out:
#    ID       y  X0 X1  X2 X3 X4  ... X378 X379 X380  X382  X383  X384  X385
# 0   0  130.81   k  v  at  a  d  ...    0    0    0     0     0     0     0
# 1   6   88.53   k  t  av  e  d  ...    0    0    0     0     0     0     0
# 2   7   76.26  az  w   n  c  d  ...    0    0    0     1     0     0     0
# 3   9   80.62  az  t   n  f  d  ...    0    0    0     0     0     0     0
# 4  13   78.02  az  v   n  f  d  ...    0    0    0     0     0     0     0
#
# [5 rows x 378 columns]

# %% [markdown]
# #export data to local disk

# %%
from google.colab import files
files.download('mercedesbenz.csv')

# %% [markdown]
# Thus the csv file will be downloaded

# %% [markdown]
# #import data from drive

# %%
from google.colab import drive
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('mercedesbenz.csv')

# %%
df.head()
# Out:
#    ID       y  X0 X1  X2 X3 X4  ... X378 X379 X380  X382  X383  X384  X385
# 0   0  130.81   k  v  at  a  d  ...    0    0    0     0     0     0     0
# 1   6   88.53   k  t  av  e  d  ...    0    0    0     0     0     0     0
# 2   7   76.26  az  w   n  c  d  ...    0    0    0     1     0     0     0
# 3   9   80.62  az  t   n  f  d  ...    0    0    0     0     0     0     0
# 4  13   78.02  az  v   n  f  d  ...    0    0    0     0     0     0     0
#
# [5 rows x 378 columns]

# %% [markdown]
# here mercedesbenz.csv files located in the drive. if it be in a folder call folder1 then we have to write like 'folder1/mercedesbenz.csv'
