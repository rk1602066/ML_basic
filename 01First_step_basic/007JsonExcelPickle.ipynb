# %%
import pandas as pd

# %%
data = '{"name":"james","email":"james@gmail.com","job_prifile":[{"title1":"sr. developer","title2":"soft. engg"}]}'

# %%
df1=pd.read_json(data)
df1
# Out:
#     name            email                                        job_prifile
# 0  james  james@gmail.com  {'title1': 'sr. developer', 'title2': 'soft. e...

# %%
df1.to_json()
# Out:
# '{"name":{"0":"james"},"email":{"0":"james@gmail.com"},"job_prifile":{"0":{"title1":"sr. developer","title2":"soft. engg"}}}'

# %%
df1.to_json(orient="records")
# Out:
# '[{"name":"james","email":"james@gmail.com","job_prifile":{"title1":"sr. developer","title2":"soft. engg"}}]'

# %%
df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data',header=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       178 non-null    int64
#  1   1       178 non-null    float64
#  2   2       178 non-null    float64
#  3   3       178 non-null    float64
#  4   4       178 non-null    float64
#  5   5       178 non-null    int64
#  6   6       178 non-null    float64
#  7   7       178 non-null    float64
#  8   8       178 non-null    float64
#  9   9       178 non-null    float64
#  10  10      178 non-null    float64
#  11  11      178 non-null    float64
#  12  12      178 non-null    float64
#  13  13      178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.head()
# Out:
#    0      1     2     3     4    5   ...    8     9     10    11    12    13
# 0   1  14.23  1.71  2.43  15.6  127  ...  0.28  2.29  5.64  1.04  3.92  1065
# 1   1  13.20  1.78  2.14  11.2  100  ...  0.26  1.28  4.38  1.05  3.40  1050
# 2   1  13.16  2.36  2.67  18.6  101  ...  0.30  2.81  5.68  1.03  3.17  1185
# 3   1  14.37  1.95  2.50  16.8  113  ...  0.24  2.18  7.80  0.86  3.45  1480
# 4   1  13.24  2.59  2.87  21.0  118  ...  0.39  1.82  4.32  1.04  2.93   735
#
# [5 rows x 14 columns]

# %%
df.to_csv('wine.csv')

# %%
df.head()
# Out:
#    0      1     2     3     4    5   ...    8     9     10    11    12    13
# 0   1  14.23  1.71  2.43  15.6  127  ...  0.28  2.29  5.64  1.04  3.92  1065
# 1   1  13.20  1.78  2.14  11.2  100  ...  0.26  1.28  4.38  1.05  3.40  1050
# 2   1  13.16  2.36  2.67  18.6  101  ...  0.30  2.81  5.68  1.03  3.17  1185
# 3   1  14.37  1.95  2.50  16.8  113  ...  0.24  2.18  7.80  0.86  3.45  1480
# 4   1  13.24  2.59  2.87  21.0  118  ...  0.39  1.82  4.32  1.04  2.93   735
#
# [5 rows x 14 columns]

# %%
df.to_json(orient="index")
# Out:
# '{"0":{"0":1,"1":14.23,"2":1.71,"3":2.43,"4":15.6,"5":127,"6":2.8,"7":3.06,"8":0.28,"9":2.29,"10":5.64,"11":1.04,"12":3.92,"13":1065},"1":{"0":1,"1":13.2,"2":1.78,"3":2.14,"4":11.2,"5":100,"6":2.65,"7":2.76,"8":0.26,"9":1.28,"10":4.38,"11":1.05,"12":3.4,"13":1050},"2":{"0":1,"1":13.16,"2":2.36,"3":2.67,"4":18.6,"5":101,"6":2.8,"7":3.24,"8":0.3,"9":2.81,"10":5.68,"11":1.03,"12":3.17,"13":1185},"3":{"0":1,"1":14.37,"2":1.95,"3":2.5,"4":16.8,"5":113,"6":3.85,"7":3.49,"8":0.24,"9":2.18,"10":7.8,"11":0.86,"12":3.45,"13":1480},"4":{"0":1,"1":13.24,"2":2.59,"3":2.87,"4":21.0,"5":118,"6":2.8,"7":2.69,"8":0.39,"9":1.82,"10":4.32,"11":1.04,"12":2.93,"13":735},"5":{"0":1,"1":14.2,"2":1.76,"3":2.45,"4":15.2,"5":112,"6":3.27,"7":3.39,"8":0.34,"9":1.97,"10":6.75,"11":1.05,"12":2.85,"13":1450},"6":{"0":1,"1":14.39,"2":1.87,"3":2.45,"4":14.6,"5":96,"6":2.5,"7":2.52,"8":0.3,"9":1.98,"10":5.25,"11":1.02,"12":3.58,"13":1290},"7":{"0":1,"1":14.06,"2":2.15,"3":2.61,"4":17.6,"5":121,"6":2.6,"7":2.51,"8":0
# ...

# %%
df.to_json(orient="records")
# Out:
# '[{"0":1,"1":14.23,"2":1.71,"3":2.43,"4":15.6,"5":127,"6":2.8,"7":3.06,"8":0.28,"9":2.29,"10":5.64,"11":1.04,"12":3.92,"13":1065},{"0":1,"1":13.2,"2":1.78,"3":2.14,"4":11.2,"5":100,"6":2.65,"7":2.76,"8":0.26,"9":1.28,"10":4.38,"11":1.05,"12":3.4,"13":1050},{"0":1,"1":13.16,"2":2.36,"3":2.67,"4":18.6,"5":101,"6":2.8,"7":3.24,"8":0.3,"9":2.81,"10":5.68,"11":1.03,"12":3.17,"13":1185},{"0":1,"1":14.37,"2":1.95,"3":2.5,"4":16.8,"5":113,"6":3.85,"7":3.49,"8":0.24,"9":2.18,"10":7.8,"11":0.86,"12":3.45,"13":1480},{"0":1,"1":13.24,"2":2.59,"3":2.87,"4":21.0,"5":118,"6":2.8,"7":2.69,"8":0.39,"9":1.82,"10":4.32,"11":1.04,"12":2.93,"13":735},{"0":1,"1":14.2,"2":1.76,"3":2.45,"4":15.2,"5":112,"6":3.27,"7":3.39,"8":0.34,"9":1.97,"10":6.75,"11":1.05,"12":2.85,"13":1450},{"0":1,"1":14.39,"2":1.87,"3":2.45,"4":14.6,"5":96,"6":2.5,"7":2.52,"8":0.3,"9":1.98,"10":5.25,"11":1.02,"12":3.58,"13":1290},{"0":1,"1":14.06,"2":2.15,"3":2.61,"4":17.6,"5":121,"6":2.6,"7":2.51,"8":0.31,"9":1.25,"10":5.05,"11":1.06
# ...

# %% [markdown]
# #webscrapping Reading html

# %%
url = 'https://www.fdic.gov/bank/individual/failed/banklist.html'

# %%
dfs = pd.read_html(url)

# %%
dfs[0]
# Out:
#                              Bank Name  ...       Closing Date
# 0                    Almena State Bank  ...   October 23, 2020
# 1           First City Bank of Florida  ...   October 16, 2020
# 2                 The First State Bank  ...      April 3, 2020
# 3                   Ericson State Bank  ...  February 14, 2020
# 4     City National Bank of New Jersey  ...   November 1, 2019
# ..                                 ...  ...                ...
# 558                 Superior Bank, FSB  ...      July 27, 2001
# 559                Malta National Bank  ...        May 3, 2001
# 560    First Alliance Bank & Trust Co.  ...   February 2, 2001
# 561  National State Bank of Metropolis  ...  December 14, 2000
# 562                   Bank of Honolulu  ...   October 13, 2000
#
# [563 rows x 6 columns]

# %%
type(dfs)
# Out:
# list

# %%
type(dfs[0])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #match with column name

# %%
url_mcc = 'https://en.wikipedia.org/wiki/Mobile_country_code'
dfs = pd.read_html(url_mcc)

# %%
dfs[0]
# Out:
#    MCC  MNC  ... Bands (MHz)                             References and notes
# 0    1    1  ...         any                                              NaN
# 1    1    1  ...         any                                              NaN
# 2  999   99  ...         any  Internal use in private networks, no roaming[4]
# 3  999  999  ...         any  Internal use in private networks, no roaming[4]
#
# [4 rows x 7 columns]

# %%
dfs[1]
# Out:
#      Mobile country code  ...                   Remarks
# 0                    289  ...  MCC is not listed by ITU
# 1                    412  ...                       NaN
# 2                    276  ...                       NaN
# 3                    603  ...                       NaN
# 4                    544  ...                       NaN
# ..                   ...  ...                       ...
# 247                  452  ...                       NaN
# 248                  543  ...                       NaN
# 249                  421  ...                       NaN
# 250                  645  ...                       NaN
# 251                  648  ...                       NaN
#
# [252 rows x 6 columns]

# %%
dfs = pd.read_html(url_mcc,match='Country',header=0)

# %%
dfs[0]
# Out:
#      Mobile country code  ...                   Remarks
# 0                    289  ...  MCC is not listed by ITU
# 1                    412  ...                       NaN
# 2                    276  ...                       NaN
# 3                    603  ...                       NaN
# 4                    544  ...                       NaN
# ..                   ...  ...                       ...
# 247                  452  ...                       NaN
# 248                  543  ...                       NaN
# 249                  421  ...                       NaN
# 250                  645  ...                       NaN
# 251                  648  ...                       NaN
#
# [252 rows x 6 columns]

# %% [markdown]
# #Read_excel files

# %%
df_excel = pd.read_excel('filename.xlsx')

# %%
df_excel.head()

# %% [markdown]
# #Excel files

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-4b307a55-5152-4a24-adc9-de21d8e77510" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b307a55-5152-4a24-adc9-de21d8e77510">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gold.xls to gold.xls

# %%
df_excel = pd.read_excel('gold.xls')

# %%
df_excel.head()
# Out:
#        gold
# 0 -0.731528
# 1 -0.444905
# 2 -0.462609
# 3  1.093151
# 4  0.558504

# %% [markdown]
# #Pickling files

# %%
df_excel.to_pickle('df_excel')

# %%
df = pd.read_pickle('df_excel')

# %%
df.head()
# Out:
#        gold
# 0 -0.731528
# 1 -0.444905
# 2 -0.462609
# 3  1.093151
# 4  0.558504
